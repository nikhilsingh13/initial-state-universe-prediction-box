# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %matplotlib inline

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, Add, Activation, Dropout

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, Reshape

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
print(tf.config.list_physical_devices('GPU'))
# Out:
# Num GPUs Available:  1
# tf.Tensor(228.28229, shape=(), dtype=float32)
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-01-12 14:00:59.384034: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-12 14:00:59.856582: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38420 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:01:00.0, compute capability: 8.0

# %%
data = np.load('./generated_data/simulated_data_010124_5K.npy')

# %%
os.environ['PYTHONHASHSEED']=str(123)

np.random.seed(123)
tf.random.set_seed(123)

# %%
# Split the data
initial_state = data[:, 0]
final_state = data[:, 1]

# Compute the mean and std of the initial and final states
initial_state_mean, initial_state_std = np.mean(initial_state), np.std(initial_state)
final_state_mean, final_state_std = np.mean(final_state), np.std(final_state)

# Normalize the initial and final states
initial_state = (initial_state - initial_state_mean) / initial_state_std
final_state = (final_state - final_state_mean) / final_state_std

# Select one simulation's initial and final states
initial_conditions = initial_state[0]
final_density = final_state[0]

# %%
# train and test
X_train, X_test, y_train, y_test  = train_test_split(initial_state, final_state, test_size=0.15, random_state=123)

# further splitting it in training and validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=123)

# %%
# Recasting dimensions to 4D tensor (suitable for 3D convolutions) with the following dimensions: (batch_size, height, width, depth, num_channels)
X_train = np.reshape(X_train, (*X_train.shape, 1))
X_val = np.reshape(X_val, (*X_val.shape, 1))
X_test = np.reshape(X_test, (*X_test.shape, 1))

y_train = np.reshape(y_train, (*y_train.shape, 1))
y_val = np.reshape(y_val, (*y_val.shape, 1))
y_test = np.reshape(y_test, (*y_test.shape, 1))

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((3612, 32, 32, 32, 1),
#  (3612, 32, 32, 32, 1),
#  (638, 32, 32, 32, 1),
#  (638, 32, 32, 32, 1),
#  (750, 32, 32, 32, 1),
#  (750, 32, 32, 32, 1))

# %%
# Parameters
Ngrid = 32  # grid size

# %%
# Configuring the input shape
input_shape = Input(shape=(Ngrid, Ngrid, Ngrid, 1))

# %%
# Building the model
x = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(input_shape)
x = MaxPooling3D((2, 2, 2), padding='same')(x)
x = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling3D((2, 2, 2), padding='same')(x)

x = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(encoded)
x = UpSampling3D((2, 2, 2))(x)
x = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(x)
x = UpSampling3D((2, 2, 2))(x)
decoded = Conv3D(1, (3, 3, 3), activation='linear', padding='same')(x)  # use a linear activation function for regression

ae_model = Model(input_shape, decoded)

# %%
# Compile the model
ae_model.compile(optimizer=Adam(), 
                   loss='mse',
                   metrics=['mae'],
                   run_eagerly=True)

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=5, 
                               restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=5, 
                              min_lr=0.001)
checkpoint = ModelCheckpoint('resnet_5K.hdf5', 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True)

# %%
history = ae_model.fit(x=X_train, 
                         y=y_train, 
                         validation_data=(X_val, y_val), 
                         batch_size=32, 
                         epochs=50, 
                         callbacks=[early_stopping, reduce_lr, checkpoint])
# Out:
# Epoch 1/50
# 2024-01-12 14:01:03.544087: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 113/113 [==============================] - ETA: 0s - loss: 1.3177 - mae: 0.7263
# Epoch 1: val_loss improved from inf to 0.82339, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 8s 46ms/step - loss: 1.3177 - mae: 0.7263 - val_loss: 0.8234 - val_mae: 0.6232 - lr: 0.0010
# Epoch 2/50
# 113/113 [==============================] - ETA: 0s - loss: 0.7698 - mae: 0.6146
# Epoch 2: val_loss improved from 0.82339 to 0.73186, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.7698 - mae: 0.6146 - val_loss: 0.7319 - val_mae: 0.5976 - lr: 0.0010
# Epoch 3/50
# 113/113 [==============================] - ETA: 0s - loss: 0.7187 - mae: 0.5950
# Epoch 3: val_loss improved from 0.73186 to 0.70553, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.7187 - mae: 0.5950 - val_loss: 0.7055 - val_mae: 0.5879 - lr: 0.0010
# Epoch 4/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6988 - mae: 0.5876
# Epoch 4: val_loss improved from 0.70553 to 0.68968, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6988 - mae: 0.5876 - val_loss: 0.6897 - val_mae: 0.5821 - lr: 0.0010
# Epoch 5/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6850 - mae: 0.5824
# Epoch 5: val_loss improved from 0.68968 to 0.67876, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.6850 - mae: 0.5824 - val_loss: 0.6788 - val_mae: 0.5810 - lr: 0.0010
# Epoch 6/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6749 - mae: 0.5785
# Epoch 6: val_loss improved from 0.67876 to 0.67022, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 5s 41ms/step - loss: 0.6749 - mae: 0.5785 - val_loss: 0.6702 - val_mae: 0.5770 - lr: 0.0010
# Epoch 7/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6671 - mae: 0.5756
# Epoch 7: val_loss improved from 0.67022 to 0.66276, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.6671 - mae: 0.5756 - val_loss: 0.6628 - val_mae: 0.5744 - lr: 0.0010
# Epoch 8/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6612 - mae: 0.5735
# Epoch 8: val_loss improved from 0.66276 to 0.66262, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 5s 43ms/step - loss: 0.6612 - mae: 0.5735 - val_loss: 0.6626 - val_mae: 0.5821 - lr: 0.0010
# Epoch 9/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6544 - mae: 0.5709
# Epoch 9: val_loss improved from 0.66262 to 0.65390, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6544 - mae: 0.5709 - val_loss: 0.6539 - val_mae: 0.5779 - lr: 0.0010
# Epoch 10/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6497 - mae: 0.5693
# Epoch 10: val_loss improved from 0.65390 to 0.64659, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6497 - mae: 0.5693 - val_loss: 0.6466 - val_mae: 0.5706 - lr: 0.0010
# Epoch 11/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6447 - mae: 0.5675
# Epoch 11: val_loss improved from 0.64659 to 0.64222, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6447 - mae: 0.5675 - val_loss: 0.6422 - val_mae: 0.5648 - lr: 0.0010
# Epoch 12/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6407 - mae: 0.5661
# Epoch 12: val_loss improved from 0.64222 to 0.64160, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6407 - mae: 0.5661 - val_loss: 0.6416 - val_mae: 0.5580 - lr: 0.0010
# Epoch 13/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6371 - mae: 0.5648
# Epoch 13: val_loss improved from 0.64160 to 0.63505, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 5s 42ms/step - loss: 0.6371 - mae: 0.5648 - val_loss: 0.6351 - val_mae: 0.5664 - lr: 0.0010
# Epoch 14/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6336 - mae: 0.5636
# Epoch 14: val_loss improved from 0.63505 to 0.63087, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.6336 - mae: 0.5636 - val_loss: 0.6309 - val_mae: 0.5637 - lr: 0.0010
# Epoch 15/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6302 - mae: 0.5624
# Epoch 15: val_loss improved from 0.63087 to 0.62913, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6302 - mae: 0.5624 - val_loss: 0.6291 - val_mae: 0.5664 - lr: 0.0010
# Epoch 16/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6272 - mae: 0.5614
# Epoch 16: val_loss improved from 0.62913 to 0.62747, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6272 - mae: 0.5614 - val_loss: 0.6275 - val_mae: 0.5574 - lr: 0.0010
# Epoch 17/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6242 - mae: 0.5603
# Epoch 17: val_loss improved from 0.62747 to 0.62316, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6242 - mae: 0.5603 - val_loss: 0.6232 - val_mae: 0.5561 - lr: 0.0010
# Epoch 18/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6218 - mae: 0.5595
# Epoch 18: val_loss improved from 0.62316 to 0.62067, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.6218 - mae: 0.5595 - val_loss: 0.6207 - val_mae: 0.5601 - lr: 0.0010
# Epoch 19/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6187 - mae: 0.5584
# Epoch 19: val_loss improved from 0.62067 to 0.61772, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 38ms/step - loss: 0.6187 - mae: 0.5584 - val_loss: 0.6177 - val_mae: 0.5593 - lr: 0.0010
# Epoch 20/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6170 - mae: 0.5579
# Epoch 20: val_loss improved from 0.61772 to 0.61587, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6170 - mae: 0.5579 - val_loss: 0.6159 - val_mae: 0.5538 - lr: 0.0010
# Epoch 21/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6141 - mae: 0.5567
# Epoch 21: val_loss improved from 0.61587 to 0.61525, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6141 - mae: 0.5567 - val_loss: 0.6153 - val_mae: 0.5642 - lr: 0.0010
# Epoch 22/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6117 - mae: 0.5560
# Epoch 22: val_loss improved from 0.61525 to 0.61040, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6117 - mae: 0.5560 - val_loss: 0.6104 - val_mae: 0.5570 - lr: 0.0010
# Epoch 23/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6094 - mae: 0.5551
# Epoch 23: val_loss improved from 0.61040 to 0.60927, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 24s 213ms/step - loss: 0.6094 - mae: 0.5551 - val_loss: 0.6093 - val_mae: 0.5607 - lr: 0.0010
# Epoch 24/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6078 - mae: 0.5546
# Epoch 24: val_loss improved from 0.60927 to 0.60737, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 5s 40ms/step - loss: 0.6078 - mae: 0.5546 - val_loss: 0.6074 - val_mae: 0.5560 - lr: 0.0010
# Epoch 25/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6060 - mae: 0.5540
# Epoch 25: val_loss improved from 0.60737 to 0.60565, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.6060 - mae: 0.5540 - val_loss: 0.6056 - val_mae: 0.5508 - lr: 0.0010
# Epoch 26/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6031 - mae: 0.5529
# Epoch 26: val_loss improved from 0.60565 to 0.60329, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 22s 192ms/step - loss: 0.6031 - mae: 0.5529 - val_loss: 0.6033 - val_mae: 0.5537 - lr: 0.0010
# Epoch 27/50
# 112/113 [============================>.] - ETA: 0s - loss: 0.6019 - mae: 0.5526
# Epoch 27: val_loss did not improve from 0.60329
# 113/113 [==============================] - 4s 38ms/step - loss: 0.6019 - mae: 0.5525 - val_loss: 0.6062 - val_mae: 0.5651 - lr: 0.0010
# Epoch 28/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5995 - mae: 0.5517
# Epoch 28: val_loss improved from 0.60329 to 0.59971, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.5995 - mae: 0.5517 - val_loss: 0.5997 - val_mae: 0.5567 - lr: 0.0010
# Epoch 29/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5983 - mae: 0.5513
# Epoch 29: val_loss improved from 0.59971 to 0.59767, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5983 - mae: 0.5513 - val_loss: 0.5977 - val_mae: 0.5549 - lr: 0.0010
# Epoch 30/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5958 - mae: 0.5503
# Epoch 30: val_loss did not improve from 0.59767
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5958 - mae: 0.5503 - val_loss: 0.5977 - val_mae: 0.5581 - lr: 0.0010
# Epoch 31/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5943 - mae: 0.5499
# Epoch 31: val_loss improved from 0.59767 to 0.59486, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.5943 - mae: 0.5499 - val_loss: 0.5949 - val_mae: 0.5465 - lr: 0.0010
# Epoch 32/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5939 - mae: 0.5498
# Epoch 32: val_loss improved from 0.59486 to 0.59318, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.5939 - mae: 0.5498 - val_loss: 0.5932 - val_mae: 0.5477 - lr: 0.0010
# Epoch 33/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5919 - mae: 0.5490
# Epoch 33: val_loss did not improve from 0.59318
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5919 - mae: 0.5490 - val_loss: 0.5936 - val_mae: 0.5576 - lr: 0.0010
# Epoch 34/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5901 - mae: 0.5484
# Epoch 34: val_loss did not improve from 0.59318
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5901 - mae: 0.5484 - val_loss: 0.5938 - val_mae: 0.5411 - lr: 0.0010
# Epoch 35/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5890 - mae: 0.5480
# Epoch 35: val_loss improved from 0.59318 to 0.58850, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.5890 - mae: 0.5480 - val_loss: 0.5885 - val_mae: 0.5466 - lr: 0.0010
# Epoch 36/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5881 - mae: 0.5477
# Epoch 36: val_loss did not improve from 0.58850
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5881 - mae: 0.5477 - val_loss: 0.5898 - val_mae: 0.5472 - lr: 0.0010
# Epoch 37/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5860 - mae: 0.5469
# Epoch 37: val_loss improved from 0.58850 to 0.58576, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5860 - mae: 0.5469 - val_loss: 0.5858 - val_mae: 0.5458 - lr: 0.0010
# Epoch 38/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5843 - mae: 0.5464
# Epoch 38: val_loss did not improve from 0.58576
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5843 - mae: 0.5464 - val_loss: 0.5894 - val_mae: 0.5424 - lr: 0.0010
# Epoch 39/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5830 - mae: 0.5458
# Epoch 39: val_loss improved from 0.58576 to 0.58409, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5830 - mae: 0.5458 - val_loss: 0.5841 - val_mae: 0.5505 - lr: 0.0010
# Epoch 40/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5826 - mae: 0.5458
# Epoch 40: val_loss improved from 0.58409 to 0.58194, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5826 - mae: 0.5458 - val_loss: 0.5819 - val_mae: 0.5488 - lr: 0.0010
# Epoch 41/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5812 - mae: 0.5453
# Epoch 41: val_loss did not improve from 0.58194
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5812 - mae: 0.5453 - val_loss: 0.5822 - val_mae: 0.5430 - lr: 0.0010
# Epoch 42/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5797 - mae: 0.5447
# Epoch 42: val_loss improved from 0.58194 to 0.58164, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 40ms/step - loss: 0.5797 - mae: 0.5447 - val_loss: 0.5816 - val_mae: 0.5524 - lr: 0.0010
# Epoch 43/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5780 - mae: 0.5441
# Epoch 43: val_loss did not improve from 0.58164
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5780 - mae: 0.5441 - val_loss: 0.5836 - val_mae: 0.5376 - lr: 0.0010
# Epoch 44/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5778 - mae: 0.5440
# Epoch 44: val_loss improved from 0.58164 to 0.58076, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 5s 40ms/step - loss: 0.5778 - mae: 0.5440 - val_loss: 0.5808 - val_mae: 0.5537 - lr: 0.0010
# Epoch 45/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5753 - mae: 0.5431
# Epoch 45: val_loss improved from 0.58076 to 0.57647, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5753 - mae: 0.5431 - val_loss: 0.5765 - val_mae: 0.5396 - lr: 0.0010
# Epoch 46/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5747 - mae: 0.5429
# Epoch 46: val_loss improved from 0.57647 to 0.57472, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5747 - mae: 0.5429 - val_loss: 0.5747 - val_mae: 0.5416 - lr: 0.0010
# Epoch 47/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5743 - mae: 0.5428
# Epoch 47: val_loss did not improve from 0.57472
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5743 - mae: 0.5428 - val_loss: 0.5784 - val_mae: 0.5480 - lr: 0.0010
# Epoch 48/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5732 - mae: 0.5425
# Epoch 48: val_loss improved from 0.57472 to 0.57241, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5732 - mae: 0.5425 - val_loss: 0.5724 - val_mae: 0.5452 - lr: 0.0010
# Epoch 49/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5705 - mae: 0.5414
# Epoch 49: val_loss did not improve from 0.57241
# 113/113 [==============================] - 4s 38ms/step - loss: 0.5705 - mae: 0.5414 - val_loss: 0.5731 - val_mae: 0.5368 - lr: 0.0010
# Epoch 50/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5703 - mae: 0.5413
# Epoch 50: val_loss improved from 0.57241 to 0.57154, saving model to resnet_5K.hdf5
# 113/113 [==============================] - 4s 39ms/step - loss: 0.5703 - mae: 0.5413 - val_loss: 0.5715 - val_mae: 0.5476 - lr: 0.0010

# %%
eval_results = ae_model.evaluate(x=X_test, y=y_test)
print(f"Evaluation Results:{eval_results}")
# Out:
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5706 - mae: 0.5473
# Evaluation Results:[0.5706343054771423, 0.5472602844238281]

# %%
predictions = ae_model.predict(X_test)
predictions.shape
# Out:
# (750, 32, 32, 32, 1)

# %%
vmin = min(np.min(predictions), np.min(X_test))
vmax = max(np.max(predictions), np.max(X_test))

vmin, vmax
# Out:
# (-5.002735977640595, 10.414035)

# %%
for test_index in range(5):  # Plot first 5 test cases
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))

    # Plot predicted initial state
    im = axs[0].imshow(predictions[test_index].reshape(Ngrid, Ngrid, Ngrid)[Ngrid//2], 
                       vmin=vmin, 
                       vmax=vmax,
                       cmap='viridis')
    axs[0].set_title('Predicted Initial State')
    fig.colorbar(im, ax=axs[0])

    # Plot true initial state
    im = axs[1].imshow(y_test[test_index].reshape(Ngrid, Ngrid, Ngrid)[Ngrid//2], 
                       vmin=vmin, 
                       vmax=vmax,
                       cmap='viridis')
    axs[1].set_title('True Initial State')
    fig.colorbar(im, ax=axs[1])

    # Plot given final state 
    im = axs[2].imshow(X_test[test_index].reshape(Ngrid, Ngrid, Ngrid)[Ngrid//2], 
                       vmin=vmin, 
                       vmax=vmax, 
                       cmap='viridis')
    axs[2].set_title('Given Final State')
    fig.colorbar(im, ax=axs[2])

    plt.show()

# %%
# calculating the error metrics
mse = mean_squared_error(y_test.flatten(), predictions.flatten())
mae = mean_absolute_error(y_test.flatten(), predictions.flatten())

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Squared Error (MSE): 0.5706342879868925
# Mean Absolute Error (MAE): 0.5472603260460221

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test.flatten(), predictions.flatten(), alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Scatter plot of True vs Predicted values')
plt.show()
